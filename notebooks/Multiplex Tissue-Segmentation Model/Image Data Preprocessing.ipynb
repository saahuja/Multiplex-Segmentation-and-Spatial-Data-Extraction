# %%
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
image = mpimg.imread("DAPI1.jpg") #read-in data
image2 = mpimg.imread("membrane.jpg") #read-in data
image.shape 
image = image[:,...,0]
image2 = image2[:,...,0]
plt.imshow(image)
plt.show()


image.shape
# Out:
# (1004, 1344)

# %%
import numpy as np
image = np.expand_dims(image, 0) #create new first dimension
image2 = np.expand_dims(image2, 0) #create new first dimension

# %%
image = image[:,...,np.newaxis] #add new axis for channel

# %%
image.shape 
image2.shape
# Out:
# (1, 1004, 1344)

# %%
image = np.repeat(image, 2, axis=3)

# %%
image.shape
# Out:
# (1, 1004, 1344, 2)

# %%
plt.imshow(image[0,...,0])

# %%
plt.imshow(image2[0,...,:])

# %%
image[:,...,1] = image2

# %%
plt.imshow(image[0,...,0])

# %%
plt.imshow(image[0,...,1])

# %% [markdown]
# # Original Test Data

# %%
import deepcell
import numpy as np
from sklearn.model_selection import train_test_split

#with urllib.request.urlopen('https://deepcell-data.s3.amazonaws.com/multiplex/20200810_tissue_dataset.npz') as f:
   # html = f.read().decode('utf-8')


filename = '20200810_tissue_dataset.npz'
test_size = 0.1 # % of data saved as test
seed = 0 # seed for random train-test split

a = np.load(filename)

print(a.files)

a['X'].shape
a['y'].shape

X_train, X_test, y_train, y_test = train_test_split(a['X'], a['y'], test_size=0.10, random_state=26)
# Out:
# ['X', 'y']

# %%
import matplotlib.pyplot as plt

i = 0
test_im = X_test[i:(i+1)]
test_im.shape
fig, ax = plt.subplots(1, 2, figsize=(10, 10))
ax[0].imshow(test_im[0, ..., 0])
ax[1].imshow(test_im[0, ..., 1])
plt.show()
